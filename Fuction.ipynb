# %% [markdown]
# <a href="https://colab.research.google.com/github/hussain1079/Ict-dsa/blob/main/Fuction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet(name):
  print("Hi",name)
greet("Messi")
# Out:
# Hi Messi

# %%
def sum(a,b):
  sum=a+b
  print(sum)
sum(10,20)
# Out:
# 30

# %%
def product(w,h):
 return w*h
product(5,5)
# Out:
# 25
