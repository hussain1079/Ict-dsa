# %% [markdown]
# <a href="https://colab.research.google.com/github/hussain1079/Ict-dsa/blob/main/controlstatement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
C=int(input("Enter the age:"))
if(C>=18):
 print("You are eligible to vote")
else:
 print("Sorry you are not eligible")
# Out:
# Enter the age:22
# You are eligible to vote

# %%
d=int(input("Enter a number "))
if(d%2==0):
  print("The number is even")
else:
  print("The number is odd")
# Out:
# Enter a number 10
# The number is even

# %%
y=int(input("Enter the number"))
z=y**3
print(z)
if(z%2==0):
  print("The number is even")
else:
  print("The number is odd")
# Out:
# Enter the number4
# 64
# The number is even

# %%
costprice=int(input("Enter cost price "))
sellingprice=int(input("Enter the sellingprice "))
profit=sellingprice-costprice
loss=costprice-sellingprice
if(profit>loss):
  print("The profit is",profit)
elif(loss>profit):
  print("The loss is",loss)
else:
  print("Their is no profit and loss")
# Out:
# Enter cost price 2500
# Enter the sellingprice 2000
# The loss is 500
